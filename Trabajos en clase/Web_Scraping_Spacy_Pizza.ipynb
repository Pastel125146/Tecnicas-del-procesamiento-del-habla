# %% [markdown]
# https://es.wikipedia.org/wiki/Pizza

# %%
# =====================================
# 1. INSTALAR LIBRERÍAS NECESARIAS
# =====================================

# Instalamos las librerías necesarias
# !pip install spacy requests beautifulsoup4 wordcloud matplotlib -q

# =====================================
# 2. DESCARGAR MODELO DE spaCy EN ESPAÑOL
# =====================================

# Descargamos el modelo de español grande de spaCy
# !python -m spacy download es_core_news_lg -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.0/568.0 MB 1.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# =====================================
# 3. IMPORTAR LIBRERÍAS
# =====================================

import requests                      # Para hacer la solicitud HTTP a Wikipedia
from bs4 import BeautifulSoup       # Para parsear el HTML
import spacy                        # Procesamiento de lenguaje natural
from spacy import displacy          # Visualización de análisis de dependencias
from collections import Counter     # Contar la frecuencia de palabras
from wordcloud import WordCloud     # Generar nube de palabras
import matplotlib.pyplot as plt     # Visualización de la nube

# %%
# =====================================
# 4. SCRAPING DE WIKIPEDIA
# =====================================

# URL del artículo
url = "https://es.wikipedia.org/wiki/Pizza"

# Hacemos la solicitud a la página
response = requests.get(url)
html = response.text

# Parseamos el HTML con BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Extraemos todos los párrafos del artículo principal (excluye tablas y menús)
parrafos = soup.find_all("p")

# Unimos el texto plano de todos los párrafos
texto = " ".join([p.get_text() for p in parrafos])

# Mostramos un fragmento del texto extraído
print(texto[:500])  # Solo para ver cómo se ve
# Out:
# La pizza es un plato hecho con una masa plana, habitualmente circular, elaborada con harina de trigo, levadura, agua y sal (a veces aceite de oliva) que tradicionalmente se cubre con salsa de tomate y mozzarella y se hornea a temperatura alta en un horno de leña.[1]​[2]​[3]​ Se venden en pizzerías y las elaboran pizzeros (pizzaiolo en italiano). Aunque se considera que su origen está en la gastronomía italiana,[2]​ específicamente la napolitana,[1]​ su consumo se extiende a casi todos los países

# %%
# =====================================
# 5. LIMPIEZA DE TEXTO
# =====================================

import re

# Eliminamos referencias [1], [2], etc. típicas de Wikipedia
texto_limpio = re.sub(r'\[\d+\]', '', texto)

# También podemos quitar saltos de línea innecesarios
texto_limpio = texto_limpio.replace('\n', ' ').strip()

# Mostramos una parte del texto limpio
print(texto_limpio[:500])
# Out:
# La pizza es un plato hecho con una masa plana, habitualmente circular, elaborada con harina de trigo, levadura, agua y sal (a veces aceite de oliva) que tradicionalmente se cubre con salsa de tomate y mozzarella y se hornea a temperatura alta en un horno de leña.​​​ Se venden en pizzerías y las elaboran pizzeros (pizzaiolo en italiano). Aunque se considera que su origen está en la gastronomía italiana,​ específicamente la napolitana,​ su consumo se extiende a casi todos los países del mundo, don

# %%
# =====================================
# 6. PROCESAMIENTO CON spaCy
# =====================================

# Cargamos el modelo de español de spaCy
import es_core_news_lg
nlp = es_core_news_lg.load()

# Procesamos el texto limpio
doc = nlp(texto_limpio)

print("Texto procesado con spaCy")
# Out:
# Texto procesado con spaCy

# %% [markdown]
# # **Etiquetado gramatical**

# %%
# =====================================
# 7. ETIQUETADO GRAMATICAL
# =====================================

print("\n Etiquetado gramatical (primeras 30 palabras):")
for token in list(doc)[:30]:  # Solo primeras 30 para no alargar
    if not token.is_space:
        print(f"'{token.text}' -> {token.pos_} ({spacy.explain(token.pos_)})")
# Out:
#  Etiquetado gramatical (primeras 30 palabras):
# 'La' -> DET (determiner)
# 'pizza' -> NOUN (noun)
# 'es' -> AUX (auxiliary)
# 'un' -> DET (determiner)
# 'plato' -> NOUN (noun)
# 'hecho' -> ADJ (adjective)
# 'con' -> ADP (adposition)
# 'una' -> DET (determiner)
# 'masa' -> NOUN (noun)
# 'plana' -> ADJ (adjective)
# ',' -> PUNCT (punctuation)
# 'habitualmente' -> ADV (adverb)
# 'circular' -> VERB (verb)
# ',' -> PUNCT (punctuation)
# 'elaborada' -> ADJ (adjective)
# 'con' -> ADP (adposition)
# 'harina' -> NOUN (noun)
# 'de' -> ADP (adposition)
# 'trigo' -> NOUN (noun)
# ',' -> PUNCT (punctuation)
# 'levadura' -> NOUN (noun)
# ',' -> PUNCT (punctuation)
# 'agua' -> NOUN (noun)
# 'y' -> CCONJ (coordinating conjunction)
# 'sal' -> NOUN (noun)
# '(' -> PUNCT (punctuation)
# 'a' -> ADP (adposition)
# 'veces' -> NOUN (noun)
# 'aceite' -> NOUN (noun)
# 'de' -> ADP (adposition)

# %%
# =====================================
# 8. DETECCIÓN DE ENTIDADES NOMBRADAS
# =====================================

if doc.ents:
    print("\n Entidades encontradas:")
    for ent in doc.ents:
        print(f"'{ent.text}' -> {ent.label_} ({spacy.explain(ent.label_)})")
else:
    print("\nNo se encontraron entidades nombradas.")
# Out:
#  Entidades encontradas:
# 'Junto con la hamburguesa' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'mundo,​​' -> PER (Named person or family.)
# 'América' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Nueva York,​ Buenos Aires' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Chicago.​​  Las técnicas e ingredientes' -> ORG (Companies, agencies, institutions, etc.)
# 'Entre los ingredientes habituales' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Italia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Campeonato Mundial de la Pizza' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Unión Europea' -> ORG (Companies, agencies, institutions, etc.)
# 'Especialidad' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'ETG)​' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Unesco' -> ORG (Companies, agencies, institutions, etc.)
# 'Patrimonio Cultural' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'El día mundial de la pizza' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Egipto' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Persia' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Grecia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Roma' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Darío I el Grande' -> PER (Named person or family.)
# 'Antigua Roma' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Panes' -> PER (Named person or family.)
# 'Ntuono' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Port'Alba' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Nápoles' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Ya en la década de 1830' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Napoli' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Alejandro Dumas' -> PER (Named person or family.)
# 'Le corricolo' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Reino de Nápoles' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Nápoles' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'América' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Las semillas de tomate provenientes de Perú' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'San Marzano' -> PER (Named person or family.)
# 'La combinación de pan' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'La vinculación con la pasta' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Nápoles' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Italia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Margarita de Saboya' -> PER (Named person or family.)
# 'Brandi' -> PER (Named person or family.)
# 'Raffaele Esposito' -> PER (Named person or family.)
# 'Gentilcore' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Borbones' -> PER (Named person or family.)
# 'La diáspora italiana' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'América' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'La harina' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'A continuación' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'La tradicional pizza napolitana' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Associazione Verace Pizza Napoletana' -> ORG (Companies, agencies, institutions, etc.)
# 'Todo este proceso' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Las pizzas rectangulares' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Italia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'La masa contiene agua' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'UNI 10791' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Associazione Verace Pizza Napoletana' -> ORG (Companies, agencies, institutions, etc.)
# 'Solo dos variantes están reconocidas: marinara y margarita' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Sicilia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Palermo' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Catania' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Siracusa' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Piamonte' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Turín' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Marcas' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'bianca con cebolla' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'bianca' -> PER (Named person or family.)
# 'rossa' -> PER (Named person or family.)
# 'crescia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Vico Equense' -> PER (Named person or family.)
# 'Milán' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Roma' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Liguria' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Provenza' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Buenos Aires' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Banchero' -> PER (Named person or family.)
# 'Agustín Banchero' -> PER (Named person or family.)
# 'Juan' -> PER (Named person or family.)
# 'fugazzetta' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'fainá,​​' -> PER (Named person or family.)
# 'Güerrín' -> PER (Named person or family.)
# 'Buenos Aires' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Por lo general' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Nueva York' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Nueva York' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Estados Unidos' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'La variante' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Chicago' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Por eso se conoce más comúnmente como deep-dish pizza' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'La corteza queda crujiente y los ingredientes' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'California' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Ed LaDou' -> PER (Named person or family.)
# 'Wolfgang Puck.​  La pizza hawaiana' -> PER (Named person or family.)
# 'Hawái' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Sam Panopoulos' -> PER (Named person or family.)
# 'Canadá' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Otra teoría' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Stromboli' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Nazzareno Romano' -> PER (Named person or family.)
# 'Filadelfia,​' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Stromboli' -> PER (Named person or family.)
# 'Detroit' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'San Luis' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Quad City' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'New Haven' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Nueva Jersey' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Trenton' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Brasil' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Las variantes que se denominan 'a la mexicana' -> MISC (Miscellaneous entities, e.g. events, nationalities, products or works of art)
# 'Escocia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Irán' -> LOC (Non-GPE locations, mountain ranges, bodies of water)
# 'Argelia' -> LOC (Non-GPE locations, mountain ranges, bodies of water)

# %%
displacy.render(doc, style='ent', jupyter=True, options={'distance': 200}) #Cada entidad aparecerá resaltada con un color distinto, y al lado dirá qué tipo de entidad es
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">La pizza es un plato hecho con una masa plana, habitualmente circular, elaborada con harina de trigo, levadura, agua y sal (a veces aceite de oliva) que tradicionalmente se cubre con salsa de tomate y mozzarella y se hornea a temperatura alta en un horno de leña.​​​ Se venden en pizzerías y las elaboran pizzeros (pizzaiolo en italiano). Aunque se considera que su origen está en la gastronomía italiana,​ específicamente la napolitana,​ su consumo se extiende a casi todos los países del mundo, donde hay variantes locales que incorporan distintos ingredientes para cubrir la masa.​
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Junto con la hamburguesa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , la pizza está considerada la comida más difundida del
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mundo,​​
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  como consecuencia de la diáspora italiana que se estableció en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     América
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a lo largo del siglo xx principalmente en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nueva York,​ Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  o
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chicago.​​  Las técnicas e ingredientes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  para elaborar pizza se han diversificado enormemente.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Entre los ingredientes habituales
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  se incluyen aceitunas, albahaca, anchoas, cebolla, champiñones, jamón, orégano, distintos tipos de queso, salami, salsas varias y tomate, entre otros. Asimismo, hay pizzas con forma cuadrada, con masas finas o gruesas, con harinas que no son de trigo,​ sin salsa de tomate o sin queso. Aunque típicamente se considera una preparación artesanal, existen pizzas preparadas de forma total o parcialmente industrializada («prepizza» o take and bake) que se venden en comercios.​  Desde 1989, tiene lugar anualmente en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  el
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Campeonato Mundial de la Pizza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , que realiza varias competiciones y premia a quienes obtengan los tres primeros lugares en cada una de ellas.​​ En la edición de 2018, participaron 773 pizzaioli (pizzeros) provenientes de 44 países.​ En 2010, la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Unión Europea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reconoció la pizza napolitana como
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Especialidad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  tradicional garantizada (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETG)​
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  y, en 2017, la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Unesco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reconoció el arte de los pizzaioli napolitanos como
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patrimonio Cultural
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  Inmaterial de la Humanidad.​
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El día mundial de la pizza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  es el 9 de febrero.​  Los antecedentes de la pizza se encuentran en el empleo del pan de trigo en las antiguas culturas de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Egipto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Persia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grecia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . En la época de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Darío I el Grande
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (521-500 a. C.), los soldados persas comían un pan plano con queso fundido y dátiles en la parte superior.​ En la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.

# %%
# =====================================
# 9. EXTRACCIÓN DE PALABRAS CLAVE
# =====================================

palabras_clave = []

for token in doc:
    # Solo palabras (sin puntuación, sin números, sin stopwords)
    if token.is_alpha and not token.is_stop:
        palabras_clave.append(token.lemma_.lower())  # Lema en minúscula

print(f"Se extrajeron {len(palabras_clave)} palabras clave.")
print("Ejemplo:", palabras_clave[:15])
# Out:
# Se extrajeron 1058 palabras clave.
# Ejemplo: ['pizza', 'plato', 'masa', 'plano', 'habitualmente', 'circular', 'elaborado', 'harina', 'trigo', 'levadura', 'agua', 'sal', 'aceite', 'oliva', 'tradicionalmente']

# %%
# =====================================
# 10. FRECUENCIAS Y NUBE DE PALABRAS
# =====================================

# Contamos las palabras más comunes
frecuencia_palabras = Counter(palabras_clave)
palabras_mas_comunes = frecuencia_palabras.most_common(15)

print("\nTop 15 palabras más frecuentes:")
for palabra, frecuencia in palabras_mas_comunes:
    print(f"- '{palabra}': {frecuencia}")
# Out:
# Top 15 palabras más frecuentes:
# - 'pizza': 66
# - 'tomate': 20
# - 'masa': 16
# - 'ingrediente': 14
# - 'queso': 12
# - 'italiano': 11
# - 'salsa': 10
# - 'variante': 10
# - 'siglo': 9
# - 'estilo': 9
# - 'encontrar': 7
# - 'pan': 7
# - 'harina': 6
# - 'mozzarella': 6
# - 'vender': 6

# %%
# Generamos la nube de palabras
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='plasma',
    max_words=15,
    stopwords=None,
    collocations=False
).generate_from_frequencies(frecuencia_palabras)

# Mostramos la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# =====================================
# 11. VISUALIZACIÓN DE RELACIONES SINTÁCTICAS
# =====================================

# Visualiza relaciones sintácticas entre palabras (solo primeras frases)
displacy.render(list(doc.sents)[:2], style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="153126e5c77a475294ce119db2c23f3d-0" class="displacy" width="7010" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">pizza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">plato</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">hecho</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">una</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">masa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">plana,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">habitualmente</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">circular,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">elaborada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">harina</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">trigo,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">levadura,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">agua</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">sal (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">veces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">aceite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">oliva)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">tradicionalmente</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">cubre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="
